# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Question no 1:**
#
# Import libraries (Numpy, pandas, matplotlib, plotly and seaborn) and then read csv file.

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb 

df = pd.read_csv("menu.csv")

# %% [markdown]
# **Question no 2:**
#
# Check statistical facts by checking all columns. Then calculate the maximum value of the following
# attributes ['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (%
# Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
columns = ['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein', 
            'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 
            'Iron (% Daily Value)']
df[columns].max()
# Out:
# Calories                     1880.0
# Total Fat                     118.0
# Carbohydrates                 141.0
# Dietary Fiber                   7.0
# Sugars                        128.0
# Protein                        87.0
# Vitamin A (% Daily Value)     170.0
# Vitamin C (% Daily Value)     240.0
# Calcium (% Daily Value)        70.0
# Iron (% Daily Value)           40.0
# dtype: float64

# %% [markdown]
# **Question no 3:**
#
# Check to see if infact there is any correlation between Calories and other independent variables by
# plotting a correlation matrix next

# %%
data = df[columns]

plt.figure(figsize=(10,6))
sb.heatmap(data.corr(), annot= True)
plt.show()

# %%
plt.figure(figsize=(9,6))
sb.set(style='whitegrid')
sb.boxplot(x= df['Calories'], y= df['Category'], data= df,hue= 'Category', width= 0.9)
plt.show()

# %% [markdown]
# **Question no 5:**
#
# Figure out which exact item contains a high quantity for ['Calories', 'Total Fat', 'Carbohydrates',
# 'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium
# (% Daily Value)', 'Iron (% Daily Value)'.

# %%
for column in columns:
    maximum = df[column].max()
    item_name = df[df[column]==maximum]['Item'].iloc[0]
    print(f'{column}: {item_name}: {maximum}')
# Out:
# Calories: Chicken McNuggets (40 piece): 1880
# Total Fat: Chicken McNuggets (40 piece): 118.0
# Carbohydrates: Chocolate Shake (Large): 141
# Dietary Fiber: Big Breakfast with Hotcakes (Large Biscuit): 7
# Sugars: McFlurry with M&M’s Candies (Medium): 128
# Protein: Chicken McNuggets (40 piece): 87
# Vitamin A (% Daily Value): Premium Bacon Ranch Salad (without Chicken): 170
# Vitamin C (% Daily Value): Minute Maid Orange Juice (Large): 240
# Calcium (% Daily Value): Strawberry Shake (Large): 70
# Iron (% Daily Value): Big Breakfast with Hotcakes (Regular Biscuit): 40

# %% [markdown]
# **Question no 6:**
#
#  Draw Stripplot for each
# category against the following
# attributes ['Calories', 'Total Fat',
# 'Carbohydrates', 'Dietary
# Fiber', 'Sugars', 'Protein',
# 'Vitamin A (% Daily Value)',
# 'Vitamin C (% Daily Value)',
# 'Calcium (% Daily Value)', 'Iron
# (% Daily Value)'.

# %%
sb .set(style='whitegrid')
plt.figure(figsize=(30,25))

plt.subplot(5, 2, 1)
sb.stripplot(data=df,x='Category',y='Calories',palette='bright')
plt.xticks(rotation=25,ha='right')
plt.title("Calories Content")

plt.subplot(5, 2, 2)
sb .stripplot(data=df,x='Category',y='Total Fat',palette='bright')
plt.title("Total Fat Content")
plt.xticks(rotation=25,ha='right')

plt.subplot(5, 2, 3)
sb .stripplot(data=df,x='Category',y='Carbohydrates',palette='bright')
plt.title("Carbohydrates Content")
plt.xticks(rotation=20,ha='right')

plt.subplot(5, 2, 4)
sb .stripplot(data=df,x='Category',y='Dietary Fiber',palette='bright')
plt.title("Dietary Fiber Content")
plt.xticks(rotation=25,ha='right')

plt.subplot(5, 2, 5)
sb .stripplot(data=df,x='Category',y='Calories',palette='bright')
plt.title("Calories Content")
plt.xticks(rotation=25,ha='right')

plt.subplot(5, 2, 6)
sb.stripplot(data=df,x='Category',y='Protein',palette='bright')
plt.title("Protein Content")
plt.xticks(rotation=25,ha='right')

plt.subplot(5, 2, 7)
sb.stripplot(data=df,x='Category',y='Vitamin A (% Daily Value)',palette='bright')
plt.title("Vitamin A (% Daily Value) Content")
plt.xticks(rotation=25,ha='right')

plt.subplot(5, 2, 8)
sb.stripplot(data=df,x='Category',y='Vitamin C (% Daily Value)', palette='bright')
plt.title("Vitamin C (% Daily Value) Content")
plt.xticks(rotation=25,ha='right')

plt.subplot(5, 2, 9)
sb.stripplot(data=df,x='Category',y='Calcium (% Daily Value)', palette='bright')
plt.title("Calcium (% Daily Value) Content")
plt.xticks(rotation=25,ha='right')

plt.subplot(5, 2, 10)
sb.stripplot(data=df,x='Category',y='Iron (% Daily Value)', palette='bright')
plt.title("Iron (% Daily Value) Content")
plt.xticks(rotation=25,ha='right')

plt.show()

# %% [markdown]
# **Question no 7:**
#
# Draw a horizontal bar graph for items in each category against the calories.
# Here is one sample for all items in Beef & Pork, you have to do it for items in each category. Also, write
# your observation.

# %%
sb.set(style="whitegrid")

category_data = df[df['Category'] == 'Breakfast']
    
plt.figure(figsize=(10, 10))
sb.barplot(x="Calories", y="Item", data=category_data)
    
plt.xlabel("Calories")
plt.ylabel("Item")

plt.show()

# %%
sb.set(style="whitegrid")

category_data = df[df['Category'] == 'Coffee & Tea']
    
plt.figure(figsize=(10, 18))
sb.barplot(x="Calories", y="Item", data=category_data)
    
plt.xlabel("Calories")
plt.ylabel("Item")

plt.show()

# %%
sb.set(style="whitegrid")

category_data = df[df['Category'] == 'Smoothies & Shakes']
    
plt.figure(figsize=(10, 7))
sb.barplot(x="Calories", y="Item", data=category_data)
    
plt.xlabel("Calories")
plt.ylabel("Item")

plt.show()

# %%
sb.set(style="whitegrid")

category_data = df[df['Category'] == 'Chicken & Fish']
    
plt.figure(figsize=(10, 7))
sb.barplot(x="Calories", y="Item", data=category_data)
    
plt.xlabel("Calories")
plt.ylabel("Item")

plt.show()

# %%
sb.set(style="whitegrid")

category_data = df[df['Category'] == 'Salads']
    
plt.figure(figsize=(10, 7))
sb.barplot(x="Calories", y="Item", data=category_data)
    
plt.xlabel("Calories")
plt.ylabel("Item")


plt.show()

# %%
sb.set(style="whitegrid")

category_data = df[df['Category'] == 'Beverages']
    
plt.figure(figsize=(10, 7))
sb.barplot(x="Calories", y="Item", data=category_data)
    
plt.xlabel("Calories")
plt.ylabel("Item")


plt.show()

# %%
sb.set(style="whitegrid")

category_data = df[df['Category'] == 'Beef & Pork']
    
plt.figure(figsize=(10, 7))
sb.barplot(x="Calories", y="Item", data=category_data)
    
plt.xlabel("Calories")
plt.ylabel("Item")


plt.show()

# %%
sb.set(style="whitegrid")

category_data = df[df['Category'] == 'Snacks & Sides']
    
plt.figure(figsize=(10, 7))
sb.barplot(x="Calories", y="Item", data=category_data)
    
plt.xlabel("Calories")
plt.ylabel("Item")


plt.show()

# %%
sb.set(style="whitegrid")

category_data = df[df['Category'] == 'Desserts']
    
plt.figure(figsize=(10, 7))
sb.barplot(x="Calories", y="Item", data=category_data)
    
plt.xlabel("Calories")
plt.ylabel("Item")


plt.show()
