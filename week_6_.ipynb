# %% [markdown]
# <a href="https://colab.research.google.com/github/zohafatimadev/ACIP/blob/main/week_6_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import plotly.express as px
from datetime import datetime

# %%
data = pd.read_csv("/content/births.csv")

# %%
data.head()
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548

# %%
data['decade'] = (data['year'] // 10) * 10

# %%
data.head()
# Out:
#    year  month  day gender  births  decade
# 0  1969      1  1.0      F    4046    1960
# 1  1969      1  1.0      M    4440    1960
# 2  1969      1  2.0      F    4454    1960
# 3  1969      1  2.0      M    4548    1960
# 4  1969      1  3.0      F    4548    1960

# %%
data.describe()
# Out:
#                year         month           day         births        decade
# count  15547.000000  15547.000000  15067.000000   15547.000000  15547.000000
# mean    1979.037435      6.515919     17.769894    9762.293561   1974.544285
# std        6.728340      3.449632     15.284034   28552.465810      6.789583
# min     1969.000000      1.000000      1.000000       1.000000   1960.000000
# 25%     1974.000000      4.000000      8.000000    4358.000000   1970.000000
# 50%     1979.000000      7.000000     16.000000    4814.000000   1970.000000
# 75%     1984.000000     10.000000     24.000000    5289.500000   1980.000000
# max     2008.000000     12.000000     99.000000  199622.000000   2000.000000

# %%
data.isnull().sum()
# Out:
# year        0
# month       0
# day       480
# gender      0
# births      0
# decade      0
# dtype: int64

# %%
births_per_decade_gender = data.groupby(['decade', 'gender'])['births'].sum().unstack()

births_per_decade_gender
# Out:
# gender         F         M
# decade
# 1960     1753634   1846572
# 1970    16263075  17121550
# 1980    18310351  19243452
# 1990    19479454  20420553
# 2000    18229309  19106428

# %%
# Step 4: Plot the trend of male and female births every decade
plt.figure(figsize=(10, 6))

sb.lineplot(data=births_per_decade_gender, markers=True, linewidth=2.5)
plt.legend(title = 'gender')
plt.show()

# %%
mean_births = data['births'].mean()
std_births = data['births'].std()

data = data[(data['births'] >= mean_births - 5 * std_births) & (data['births'] <= mean_births + 5 * std_births)]

# %%
data['date'] = pd.to_datetime(data[['year', 'month', 'day']], errors='coerce')
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py:1256: RuntimeWarning: invalid value encountered in cast
#   masked_result = calc(carg[mask].astype(np.float64).astype(np.int64))

# %%
data['weekday'] = data['date'].dt.day_name()
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
data_only_weekdays = data[data['weekday'].isin(weekdays)]

# %%
births_by_weekday = data_only_weekdays.groupby(['decade', 'weekday'])['births'].sum().unstack()
births_by_weekday
# Out:
# weekday   Friday   Monday  Thursday  Tuesday  Wednesday
# decade
# 1960      531220   526638    517742   549754     537910
# 1970     4992508  4895418   4903588  5090433    4949892
# 1980     5069502  4949739   5013476  5173612    5045584

# %%
births_by_weekday.plot(kind='bar', figsize=(10, 6))
plt.show()

# %%
data_by_month = data.groupby('month')['births'].sum().reset_index()
data_by_day = data.groupby('day')['births'].sum().reset_index()
data_by_month
# Out:
#     month   births
# 0       1  5759568
# 1       2  7582391
# 2       3  5868651
# 3       4  5712231
# 4       5  5785602
# 5       6  5759233
# 6       7  6220777
# 7       8  6310276
# 8       9  6206785
# 9      10  6056193
# 10     11  6149799
# 11     12  5905087

# %%
data_plot = data[data['year'] == 1969]
data_plot['month_name'] = data_plot['date'].dt.month_name()
fig = px.line(data_plot, x= 'date', y='births')
fig.show()
# Out:
# <ipython-input-18-f70e70f966c4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_plot['month_name'] = data_plot['date'].dt.month_name()
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b9b2183c-cce2-4790-af8a-e18cd1192632" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9b2183c-cce2-4790-af8a-e18cd1192632")) {                    Plotly.newPlot(                        "b9b2183c-cce2-4790-af8a-e18cd1192632",                        [{"hovertemplate":"date=%{x}\u003cbr\u003ebirths=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["1969-01-01T00:00:00","1969-01-01T00:00:00","1969-01-02T00:00:00","1969-01-02T00:00:00","1969-01-03T00:00:00","1969-01-03T00:00:00","1969-01-04T00:00:00","1969-01-04T00:00:00","1969-01-05T00:00:00","1969-01-05T00:00:00","1969-01-06T00:00:00","1969-01-06T00:00:00","1969-01-07T00:00:00","1969-01-07T00:00:00","1969-01-08T00:00:00","1969-01-08T00:00:00","1969-01-09T00:00:00","1969-01-09T00:00:00","1969-01-10T00:00:00","1969-01-10T00:00:00","1969-01-11T00:00:00","1969-01-11T00:00:00","1969-01-12T00:00:00","1969-01-12T00:00:00","1969-01-13T00:00:00","1969-01-13T00:00:00","1969-01-14T00:00:00","1969-01-14T00:00:00","1969-01-15T00:00:00","1969-01-15T00:00:00","1969-01-16T00:00:00","1969-01-16T00:00:00","1969-01-17T00:00:00","1969-01-17T00:00:00","1969-01-18T00:00:00","1969-01-18T00:00:00","1969-01-19T00:00:00","1969-01-19T00:00:00","1969-01-20T00:00:00","1969-01-20T00:00:00","1969-01-21T00:00:00","1969-01-21T00:00:00","1969-01-22T00:00:00","1969-01-22T00:00:00","1969-01-23T00:00:00","1969-01-23T00:00:00","1969-01-24T00:00:00","1969-01-24T00:00:00","1969-01-25T00:00:00","1969-01-25T00:00:00","1969-01-26T00:00:00","1969-01-26T00:00:00","1969-01-27T00:00:00","1969-01-27T00:00:00","1969-01-28T00:00:00","1969-01-28T00:00:00","1969-01-29T00:00:00","1969-01-29T00:00:00","1969-01-30T00:00:00","1969-01-30T00:00:00","1969-01-31T00:00:00","1969-01-31T00:00:00",null,null,"1969-02-01T00:00:00","1969-02-01T00:00:00","1969-02-02T00:00:00","1969-02-02T00:00:00","1969-02-03T00:00:00","1969-02-03T00:00:00","1969-02-04T00:00:00","1969-02-04T00:00:00","1969-02-05T00:00:00","1969-02-05T00:00:00","1969-02-06T00:00:00","1969-02-06T00:00:00","1969-02-07T00:00:00","1969-02-07T00:00:00","1969-02-08T00:00:00","1969-02-08T00:00:00","1969-02-09T00:00:00","1969-02-09T00:00:00","1969-02-10T00:00:00","1969-02-10T00:00:00","1969-02-11T00:00:00","1969-02-11T00:00:00","1969-02-12T00:00:00","1969-02-12T00:00:00","1969-02-13T00:00:00","1969-02-13T00:00:00","1969-02-14T00:00:00","1969-02-14T00:00:00","1969-02-15T00:00:00","1969-02-15T00:00:00","1969-02-16T00:00:00","1969-02-16T00:00:00","1969-02-17T00:00:00","1969-02-17T00:00:00","1969-02-18T00:00:00","1969-02-18T00:00:00","1969-02-19T00:00:00","1969-02-19T00:00:00","1969-02-20T00:00:00","1969-02-20T00:00:00","1969-02-21T00:00:00","1969-02-21T00:00:00","1969-02-22T00:00:00","1969-02-22T00:00:00","1969-02-23T00:00:00","1969-02-23T00:00:00","1969-02-24T00:00:00","1969-02-24T00:00:00","1969-02-25T00:00:00","1969-02-25T00:00:00","1969-02-26T00:00:00","1969-02-26T00:00:00","1969-02-27T00:00:00","1969-02-27T00:00:00","1969-02-28T00:00:00","1969-02-28T00:00:00",null,null,null,null,null,null,null,null,"1969-03-01T00:00:00","1969-03-01T00:00:00","1969-03-02T00:00:00","1969-03-02T00:00:00","1969-03-03T00:00:00","1969-03-03T00:00:00","1969-03-04T00:00:00","1969-03-04T00:00:00","1969-03-05T00:00:00","1969-03-05T00:00:00","1969-03-06T00:00:00","1969-03-06T00:00:00","1969-03-07T00:00:00","1969-03-07T00:00:00","1969-03-08T00:00:00","1969-03-08T00:00:00","1969-03-09T00:00:00","1969-03-09T00:00:00","1969-03-10T00:00:00","1969-03-10T00:00:00","1969-03-11T00:00:00","1969-03-11T00:00:00","1969-03-12T00:00:00","1969-03-12T00:00:00","1969-03-13T0 ...
